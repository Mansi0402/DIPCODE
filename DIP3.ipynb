# %%
def convert_spaces(input_path, output_path, replacement_char='_'):
    try:
        with open(input_path, 'r') as infile:
            content = infile.read()
            converted_content = content.replace(' ', replacement_char)
        with open(output_path, 'w') as outfile:
            outfile.write(converted_content)
        print(f"Spaces converted and saved to {output_path} with replacement character '_'.")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    # Example usag
    input_path = "input.txt"
    output_path = "output.txt"
    replacement_char = '_'
    convert_spaces(input_path, output_path, replacement_char)
# Out:
# Spaces converted and saved to output.txt with replacement character '_'.

# %%
import cv2
from PIL import Image
path = r'D:\flower.jpg'
image = Image.open(path)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x417>

# %%
from IPython.display import display, Image
path = r'D:\flower.jpg'
src = cv2.imread(path) 
window_name = 'Image'
image = cv2.cvtColor(src, cv2.COLOR_BGR2HSV) 
cv2.imwrite('output.jpg', image)
display(Image(filename='output.jpg'))

# %%
import cv2  
from IPython.display import display, Image
path = r'D:\flower.jpg'
src = cv2.imread(path) 
window_name = 'Image'
gray_image = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
cv2.imwrite('output.jpg', gray_image)
display(Image(filename='output.jpg'))

# %%
import cv2  
from IPython.display import display, Image
path = r'D:\flower.jpg'
src = cv2.imread(path) 
window_name = 'Image'
lab_image = cv2.cvtColor(src, cv2.COLOR_BGR2LAB)
cv2.imwrite('output.jpg', lab_image)
display(Image(filename='output.jpg'))

# %%
import cv2  
from IPython.display import display, Image
path = r'D:\flower.jpg'
src = cv2.imread(path) 
window_name = 'Image'
XYZ_image = cv2.cvtColor(src, cv2.COLOR_BGR2XYZ)
cv2.imwrite('output.jpg', XYZ_image)
display(Image(filename='output.jpg'))
